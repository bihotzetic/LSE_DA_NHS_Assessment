# %% [markdown]
# # Assignment: Diagnostic Analysis using Python

# %% [markdown]
# ## Assignment Activity: Prepare your GitHub repository

# %% [markdown]
# # My GitHub repository
#
# https://github.com/bihotzetic/LSE_DA_NHS_Assessment

# %% [markdown]
# ## Assignment Activity: Import and explore the data

# %% [markdown]
# ### Prepare the workstation

# %%
# Import the necessary libraries
import numpy as np
import pandas as pd

# %%
# Create DataFrames to store datasets
# Read the CSV and Excel files
ad = pd.read_csv('actual_duration.csv')
ar = pd.read_csv('appointments_regional.csv')
nc = pd.read_excel('national_categories.xlsx')

# %% [markdown]
# **AD - Actual Duration**

# %%
# Viewing the first 5 rows of the DataFrame, print() not used for better visual analysis
ad.head(5)
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# Viewing the last 5 rows of the DataFrame
ad.tail(5)
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                  sub_icb_location_name icb_ons_code region_ons_code  \
# 137788  NHS West Yorkshire ICB - X2C4Y    E54000054       E40000012
# 137789  NHS West Yorkshire ICB - X2C4Y    E54000054       E40000012
# 137790  NHS West Yorkshire ICB - X2C4Y    E54000054       E40000012
# 137791  NHS West Yorkshire ICB - X2C4Y    E54000054       E40000012
# 137792  NHS West Yorkshire ICB - X2C4Y    E54000054       E40000012
#
#        appointment_date actual_duration  count_of_appointments
# 137788        30-Jun-22   31-60 Minutes                    430
# 137789        30-Jun-22   21-30 Minutes                    751
# ...

# %%
# Defining the column names as a list
ad_cols = list(ad.columns)

# Viewing the column names
print("ad column names:",ad_cols)
# Out:
# ad column names: ['sub_icb_location_code', 'sub_icb_location_ons_code', 'sub_icb_location_name', 'icb_ons_code', 'region_ons_code', 'appointment_date', 'actual_duration', 'count_of_appointments']

# %%
# Determining the number of rows and columns
print("(rows,columns) =",ad.shape)
# Out:
# (rows,columns) = (137793, 8)

# %%
# Determining the data types
ad.dtypes
# Out:
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %%
# Determining sum of missing values per column
ad.isnull().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %%
# Displaying the descriptive statisics of the data, print not used for better visual analysis
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Displaying the metadata
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %% [markdown]
# **AR - Appointments Regional**

# %%
# Viewing the first 5 rows of the DataFrame
ar.head(5)
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Viewing the last 5 rows of the DataFrame
ar.tail(5)
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10

# %%
# Defining the column names as a list
ar_cols = list(ar.columns)

# Viewing the column names
print("ar column names:",ar_cols)
# Out:
# ar column names: ['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type', 'appointment_mode', 'time_between_book_and_appointment', 'count_of_appointments']

# %%
# Determining the number of rows and columns
print("(rows,columns) =",ar.shape)
# Out:
# (rows,columns) = (596821, 7)

# %%
# Determining the data types
ar.dtypes
# Out:
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
# Determining sum of missing values per column
ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Displaying the descriptive statisics of the data, print not used for better visual analysis
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Displaying the metadata
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %% [markdown]
# **NC - National Categories**

# %%
# Viewing the first 5 rows of the DataFrame
nc.head(5)
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Viewing the last 5 rows of the DataFrame
nc.tail(5)
# Out:
#        appointment_date icb_ons_code           sub_icb_location_name  \
# 817389       2022-06-30    E54000054  NHS West Yorkshire ICB - X2C4Y
# 817390       2022-06-30    E54000054  NHS West Yorkshire ICB - X2C4Y
# 817391       2022-06-30    E54000054  NHS West Yorkshire ICB - X2C4Y
# 817392       2022-06-30    E54000054  NHS West Yorkshire ICB - X2C4Y
# 817393       2022-06-30    E54000054  NHS West Yorkshire ICB - X2C4Y
#
#                   service_setting            context_type  \
# 817389  Extended Access Provision  Care Related Encounter
# 817390  Extended Access Provision  Care Related Encounter
# 817391  Extended Access Provision  Care Related Encounter
# 817392  Extended Access Provision  Care Related Encounter
# 817393  Extended Access Provision  Care Related Encounter
#
#                    national_category  count_of_appointments appointment_month
# 817389   Unplanned Clinical Activity                     12           2022-06
# ...

# %%
# Defining the column names as a list
nc_cols = list(nc.columns)

# Viewing the column names
print("nc column names:",nc_cols)
# Out:
# nc column names: ['appointment_date', 'icb_ons_code', 'sub_icb_location_name', 'service_setting', 'context_type', 'national_category', 'count_of_appointments', 'appointment_month']

# %%
# Determining the number of rows and columns
print("(rows,columns) =",nc.shape)
# Out:
# (rows,columns) = (817394, 8)

# %%
# Determining the data types
nc.dtypes
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# Determining sum of missing values per column
nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Displaying the descriptive statisics of the data, print not used for better visual analysis
nc.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %%
# Displaying the metadata
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Counting the number of unique locations
count_loc_ad = len(ad['sub_icb_location_name'].unique())
print("Count of locations ad:", count_loc_ad) 

count_loc_nc = len(nc['sub_icb_location_name'].unique())
print("Count of locations nc:", count_loc_nc)
# Out:
# Count of locations ad: 106
# Count of locations nc: 106

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Defining top locations by record count
# Counting the values and sorting highest to lowest
top_loc_ad = ad['sub_icb_location_name'].value_counts().sort_values(ascending = False).head(5)

print("Top 5 locations with highest records ad\n")
print(top_loc_ad)

top_loc_nc = nc['sub_icb_location_name'].value_counts().sort_values(ascending = False).head(5)

print("\nTop 5 locations with highest records nc\n")
print(top_loc_nc)
# Out:
# Top 5 locations with highest records ad
#
# NHS Norfolk and Waveney ICB - 26A                       1484
# NHS Kent and Medway ICB - 91Q                           1484
# NHS North West London ICB - W2U3Z                       1484
# NHS Bedfordshire Luton and Milton Keynes ICB - M1J4Y    1484
# NHS Greater Manchester ICB - 14L                        1484
# Name: sub_icb_location_name, dtype: int64
#
# Top 5 locations with highest records nc
#
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
# Name: sub_icb_location_name, dtype: int64

# %%
# Displaying the top locations with the smallest records
top_loc_nc = nc['sub_icb_location_name'].value_counts().sort_values(ascending = True).head(5)
top_loc_ad = ad['sub_icb_location_name'].value_counts().sort_values(ascending = True).head(5)
print("\nTop 5 locations with smallest records nc\n")
print(top_loc_nc)
print("\nTop 5 locations with smallest records ad\n")
print(top_loc_ad)
# Out:
# Top 5 locations with smallest records nc
#
# NHS Greater Manchester ICB - 00V              2170
# NHS Cheshire and Merseyside ICB - 01T         3242
# NHS Cheshire and Merseyside ICB - 01V         3496
# NHS Lancashire and South Cumbria ICB - 02G    4169
# NHS North East and North Cumbria ICB - 00N    4210
# Name: sub_icb_location_name, dtype: int64
#
# Top 5 locations with smallest records ad
#
# NHS Cheshire and Merseyside ICB - 01F             1013
# NHS South Yorkshire ICB - 02P                     1022
# NHS North East and North Cumbria ICB - 00P        1025
# NHS South Yorkshire ICB - 03L                     1028
# NHS Staffordshire and Stoke-on-Trent ICB - 05D    1051
# Name: sub_icb_location_name, dtype: int64

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# ounting the number of service setting
nc_ser_set = nc['service_setting'].value_counts()
print(nc_ser_set,"\n")
print("The number of service settings is",nc_ser_set.count(),"and the total sum of service settings is",nc_ser_set.sum())
# Out:
# General Practice             359274
# Primary Care Network         183790
# Other                        138789
# Extended Access Provision    108122
# Unmapped                      27419
# Name: service_setting, dtype: int64
#
# The number of service settings is 5 and the total sum of service settings is 817394

# %%
# Counting the number of context types
nc_con_typ = nc['context_type'].value_counts()
print(nc_con_typ,"\n")
print("The number of context types is",nc_con_typ.count(),"and the total sum of context types is",nc_con_typ.sum())
# Out:
# Care Related Encounter    700481
# Inconsistent Mapping       89494
# Unmapped                   27419
# Name: context_type, dtype: int64
#
# The number of context types is 3 and the total sum of context types is 817394

# %%
# Counting the number of national categories
nc_nat_cat = nc['national_category'].value_counts()
print(nc_nat_cat,"\n")
print("The number of national categories is",nc_nat_cat.count(),"and the total sum of national categories is",nc_nat_cat.sum())
# Out:
# Inconsistent Mapping                                                   89494
# General Consultation Routine                                           89329
# General Consultation Acute                                             84874
# Planned Clinics                                                        76429
# Clinical Triage                                                        74539
# Planned Clinical Procedure                                             59631
# Structured Medication Review                                           44467
# Service provided by organisation external to the practice              43095
# Home Visit                                                             41850
# Unplanned Clinical Activity                                            40415
# Patient contact during Care Home Round                                 28795
# Unmapped                                                               27419
# ...

# %%
# Counting the number of appointments statuses
ar_app_stat = ar['appointment_status'].value_counts()
print(ar_app_stat,"\n")
print("The number of appointment statuses is",ar_app_stat.count(),"and the total sum of appointment statuses is",ar_app_stat.sum())
# Out:
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: appointment_status, dtype: int64
#
# The number of appointment statuses is 3 and the total sum of appointment statuses is 596821

# %% [markdown]
# ## Assignment Activity: Analyse the data

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %%
# Create DataFrames to store datasets
# Read the CSV and Excel files
ad = pd.read_csv('actual_duration.csv')
ar = pd.read_csv('appointments_regional.csv')
nc = pd.read_excel('national_categories.xlsx')

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format
nc['appointment_date'].head(5)
# Out:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format
ad['appointment_date'].head(5)
# Out:
# 0    01-Dec-21
# 1    01-Dec-21
# 2    01-Dec-21
# 3    01-Dec-21
# 4    01-Dec-21
# Name: appointment_date, dtype: object

# %%
# View the columns of the DataFrames
print(nc.columns,"\n")
print(ad.columns,"\n")
# Out:
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
#
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')

# %%
# View the data type of the appointment_date column
print(nc.dtypes,"\n")
print(ad.dtypes)

# Note that nc appointment_date data type is already datetime
# Note that ad appointment_date datatype is a string
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object
#
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %%
# Change the date format of ad['appointment_date'] to datetime
from datetime import datetime
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])
# View the data type
ad.dtypes
# Out:
# sub_icb_location_code                object
# sub_icb_location_ons_code            object
# sub_icb_location_name                object
# icb_ons_code                         object
# region_ons_code                      object
# appointment_date             datetime64[ns]
# actual_duration                      object
# count_of_appointments                 int64
# dtype: object

# %%
# View the updated DataFrame
ad.head(5)
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0       2021-12-01           31-60 Minutes                    364
# 1       2021-12-01           21-30 Minutes                    619
# ...

# %%
# Defining the min appointment date values
nc_min_app = nc.appointment_date.min()
ad_min_app = ad.appointment_date.min()
# Defining the max appointment date values
nc_max_app = nc.appointment_date.max()
ad_max_app = ad.appointment_date.max()

# %%
print("nc appointment dates were scheduled between", nc_min_app, "and", nc_max_app,"\n")
print("ad appointment dates were scheduled between", ad_min_app, "and", ad_max_app)
# Out:
# nc appointment dates were scheduled between 2021-08-01 00:00:00 and 2022-06-30 00:00:00
#
# ad appointment dates were scheduled between 2021-12-01 00:00:00 and 2022-06-30 00:00:00

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# Subsetting the NHS North West London ICB - W2U3Z locations
nc_subset = nc.loc[nc.sub_icb_location_name=="NHS North West London ICB - W2U3Z",:]

# %%
# Adding time subset to location subset

# Creating the start and end time range
nc_start_datetime = datetime.strptime('2022-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')
nc_end_datetime = datetime.strptime('2022-06-30 05:00:00', '%Y-%m-%d %H:%M:%S')

# Defining the time subset
nc_time_ss = nc_subset.loc[(nc_subset['appointment_date'] >= nc_start_datetime) & 
                           (nc_subset['appointment_date'] <= nc_end_datetime)]

# Resetting the index of the new subset, dropping the old index
nc_time_ss.reset_index(drop = True, inplace = True)

# Displaying the time subset head to verify correct dates
nc_time_ss.head(3)
# Out:
#   appointment_date icb_ons_code              sub_icb_location_name  \
# 0       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 1       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
# 2       2022-01-01    E54000027  NHS North West London ICB - W2U3Z
#
#         service_setting            context_type     national_category  \
# 0              Unmapped                Unmapped              Unmapped
# 1  Primary Care Network  Care Related Encounter       Clinical Triage
# 2                 Other    Inconsistent Mapping  Inconsistent Mapping
#
#    count_of_appointments appointment_month
# 0                    496           2022-01
# 1                     19           2022-01
# 2                      1           2022-01

# %%
# Displaying the time subset tail to verify correct dates
nc_time_ss.tail(3)
# Out:
#      appointment_date icb_ons_code              sub_icb_location_name  \
# 7036       2022-06-30    E54000027  NHS North West London ICB - W2U3Z
# 7037       2022-06-30    E54000027  NHS North West London ICB - W2U3Z
# 7038       2022-06-30    E54000027  NHS North West London ICB - W2U3Z
#
#                 service_setting            context_type  \
# 7036  Extended Access Provision  Care Related Encounter
# 7037  Extended Access Provision  Care Related Encounter
# 7038           General Practice  Care Related Encounter
#
#                                       national_category  \
# 7036                         General Consultation Acute
# 7037                                    Clinical Triage
# 7038  Service provided by organisation external to t...
#
#       count_of_appointments appointment_month
# 7036                    217           2022-06
# 7037                    103           2022-06
# 7038                     24           2022-06

# %%
# Pivoting the columns and finding the sum of appointments
nc_time_subset_ss = pd.pivot_table(nc_time_ss, values='count_of_appointments', columns='service_setting',
                                   aggfunc = sum)

# %%
# Transposing the DataFrame for better visual analysis
nc_time_subset_ss = nc_time_subset_ss.transpose()
# Displaying the DataFrame ranked by appointments
nc_time_subset_ss.sort_values('count_of_appointments', ascending=False)
# Out:
#                            count_of_appointments
# service_setting
# General Practice                         5719516
# Unmapped                                  462758
# Other                                     181576
# Primary Care Network                      130526
# Extended Access Provision                 115052

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Calculating the total number of appoinemnts per month by grouping in nc and ar
nc_apps = nc.groupby(by='appointment_month').sum()

ar_apps = ar.groupby(by='appointment_month').sum()

# %%
# Sorting the values descending nc
nc_apps.sort_values(by='count_of_appointments',ascending=False)
# Out:
#                    count_of_appointments
# appointment_month
# 2021-11                         30405070
# 2021-10                         30303834
# 2022-03                         29595038
# 2021-09                         28522501
# 2022-05                         27495508
# 2022-06                         25828078
# 2022-01                         25635474
# 2022-02                         25355260
# 2021-12                         25140776
# 2022-04                         23913060
# 2021-08                         23852171

# %%
# Sorting the values descending ar
ar_apps.sort_values(by='count_of_appointments',ascending=False)
# Out:
#                    count_of_appointments
# appointment_month
# 2021-11                         30405070
# 2021-10                         30303834
# 2022-03                         29595038
# 2021-09                         28522501
# 2020-10                         28301932
# 2022-05                         27495508
# 2021-03                         27225424
# 2020-01                         27199296
# 2021-06                         26784182
# 2020-09                         26714255
# 2022-06                         25828078
# 2021-07                         25739219
# 2022-01                         25635474
# 2022-02                         25355260
# 2021-12                         25140776
# 2020-11                         25061602
# 2020-02                         24104621
# 2020-03                         24053468
# 2022-04                         23913060
# 2021-04                         23879932
# 2021-08                         23852171
# ...

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Grouping the number of records for each month
nc_num_rec = nc.groupby(by='appointment_month').count()

# Dropping all unnecessary columns as only one is required
nc_num_rec = nc_num_rec.drop(['appointment_date','icb_ons_code',
                                            'sub_icb_location_name','service_setting',
                                            'count_of_appointments','national_category']
                                           ,axis=1)

# Renaming the column name
nc_num_rec = nc_num_rec.rename(columns={'context_type':'number_of_records'})

# Viewing the DataFrame
nc_num_rec
# Out:
#                    number_of_records
# appointment_month
# 2021-08                        69999
# 2021-09                        74922
# 2021-10                        74078
# 2021-11                        77652
# 2021-12                        72651
# 2022-01                        71896
# 2022-02                        71769
# 2022-03                        82822
# 2022-04                        70012
# 2022-05                        77425
# 2022-06                        74168

# %%
# Grouping the number of records for each month
ar_num_rec = ar.groupby(by='appointment_month').count()

# Dropping all unnecessary columns as only one is required
ar_num_rec = ar_num_rec.drop(['icb_ons_code','appointment_status','hcp_type',
                              'time_between_book_and_appointment','count_of_appointments']
                             ,axis=1)

# Renaming the column name
ar_num_rec = ar_num_rec.rename(columns={'appointment_mode':'number_of_records'})

# Viewing the DataFrame
ar_num_rec
# Out:
#                    number_of_records
# appointment_month
# 2020-01                        20889
# 2020-02                        20689
# 2020-03                        21350
# 2020-04                        19124
# 2020-05                        18338
# 2020-06                        18844
# 2020-07                        19502
# 2020-08                        19247
# 2020-09                        20043
# 2020-10                        20122
# 2020-11                        19675
# 2020-12                        19394
# 2021-01                        19319
# 2021-02                        18949
# 2021-03                        19369
# 2021-04                        19452
# 2021-05                        19384
# 2021-06                        19814
# 2021-07                        19899
# 2021-08                        19786
# 2021-09                        20441
# 2021-10                        20562
# 2021-11                        20766
# 2021-12                        20393
# ...

# %% [markdown]
# ## Assignment activity : Visualise and identify initial trends

# %% [markdown]
# ### Prepare the workstation

# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Set figure size
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white
sns.set_style('white')

# %%
# Create DataFrames to store datasets
# Read the CSV and Excel files
ad = pd.read_csv('actual_duration.csv')
ar = pd.read_csv('appointments_regional.csv')
nc = pd.read_excel('national_categories.xlsx')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Checking the data type of appointment_month
nc.dtypes
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# Appointment month is already a string
# However it can be converted to string from below line
nc['appointment_month'] = nc['appointment_month'].astype('str')

# %%
# Aggregate on monthly level and determine the sum of records per month.
nc_ta = nc.groupby(by='appointment_month').sum()

# Resetting the index
nc_ta.reset_index()
# Out:
#    appointment_month  count_of_appointments
# 0            2021-08               23852171
# 1            2021-09               28522501
# 2            2021-10               30303834
# 3            2021-11               30405070
# 4            2021-12               25140776
# 5            2022-01               25635474
# 6            2022-02               25355260
# 7            2022-03               29595038
# 8            2022-04               23913060
# 9            2022-05               27495508
# 10           2022-06               25828078

# %%
# Plotting total appointments per month
sns.lineplot(y='count_of_appointments',x='appointment_month',data=nc_ta,ci=None)

plt.title('Total Appointments per Month')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Service settings:**

# %%
# Creating the new DataFrame
nc_ss = nc.groupby(['appointment_month','service_setting']).sum()

# Resetting the index
nc_ss.reset_index()
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08           General Practice               21575852
# 2            2021-08                      Other                 449101
# 3            2021-08       Primary Care Network                 432448
# 4            2021-08                   Unmapped                1233843
# 5            2021-09  Extended Access Provision                 187906
# 6            2021-09           General Practice               25940821
# 7            2021-09                      Other                 527174
# 8            2021-09       Primary Care Network                 530485
# 9            2021-09                   Unmapped                1336115
# 10           2021-10  Extended Access Provision                 209539
# 11           2021-10           General Practice               27606171
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=nc_ss,ci=None,
             hue='service_setting')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Service Settings per Month')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %%
# Dropping all the rows with the overrepresented General Practice 
nc_ss_no_gp = nc.drop(nc[nc.service_setting == "General Practice"].index)

# Creating the new DataFrame
nc_ss_no_gp = nc_ss_no_gp.groupby(['appointment_month','service_setting']).sum()

# Viewing the DataFrame
nc_ss_no_gp.head(5)
# Out:
#                                              count_of_appointments
# appointment_month service_setting
# 2021-08           Extended Access Provision                 160927
#                   Other                                     449101
#                   Primary Care Network                      432448
#                   Unmapped                                 1233843
# 2021-09           Extended Access Provision                 187906

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=nc_ss_no_gp,ci=None,
             hue='service_setting')

plt.title('Service Settings per Month No GP')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Context types:**

# %%
# Creating the new DataFrame
nc_ct = nc.groupby(['appointment_month','context_type']).sum()

# Resetting the index
nc_ct.reset_index()
# Out:
#    appointment_month            context_type  count_of_appointments
# 0            2021-08  Care Related Encounter               20255235
# 1            2021-08    Inconsistent Mapping                2363093
# 2            2021-08                Unmapped                1233843
# 3            2021-09  Care Related Encounter               24404251
# 4            2021-09    Inconsistent Mapping                2782135
# 5            2021-09                Unmapped                1336115
# 6            2021-10  Care Related Encounter               26125201
# 7            2021-10    Inconsistent Mapping                2811977
# 8            2021-10                Unmapped                1366656
# 9            2021-11  Care Related Encounter               26282778
# 10           2021-11    Inconsistent Mapping                2865796
# 11           2021-11                Unmapped                1256496
# 12           2021-12  Care Related Encounter               21798612
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=nc_ct,ci=None,
            hue='context_type')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Context Type per Month')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **National categories:**

# %%
# Creating the new DataFrame
nc_nc = nc.groupby(['appointment_month','national_category']).sum()

# Resetting the index
nc_nc.reset_index()
# Out:
#     appointment_month                                  national_category  \
# 0             2021-08  Care Home Needs Assessment & Personalised Care...
# 1             2021-08                                    Care Home Visit
# 2             2021-08                                    Clinical Triage
# 3             2021-08                         General Consultation Acute
# 4             2021-08                       General Consultation Routine
# ..                ...                                                ...
# 193           2022-06                         Social Prescribing Service
# 194           2022-06                       Structured Medication Review
# 195           2022-06                                           Unmapped
# 196           2022-06                        Unplanned Clinical Activity
# 197           2022-06                                            Walk-in
#
#      count_of_appointments
# 0                    29676
# 1                    47583
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=nc_nc,ci=None,
                 hue='national_category',palette='colorblind')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('National Category per Month')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %%
# Creating the new DataFrame
nc_ss_day = nc_nc = nc.groupby(by=['appointment_date','appointment_month',
                                   'service_setting']).sum()

# Resetting index
nc_ss_day = nc_ss_day.reset_index()

# Viewing the DataFrame
nc_ss_day
# Out:
#      appointment_date appointment_month            service_setting  \
# 0          2021-08-01           2021-08  Extended Access Provision
# 1          2021-08-01           2021-08           General Practice
# 2          2021-08-01           2021-08                      Other
# 3          2021-08-01           2021-08       Primary Care Network
# 4          2021-08-01           2021-08                   Unmapped
# ...               ...               ...                        ...
# 1665       2022-06-30           2022-06  Extended Access Provision
# 1666       2022-06-30           2022-06           General Practice
# 1667       2022-06-30           2022-06                      Other
# 1668       2022-06-30           2022-06       Primary Care Network
# 1669       2022-06-30           2022-06                   Unmapped
#
#       count_of_appointments
# 0                       438
# 1                      3411
# 2                       401
# 3                       323
# ...

# %% [markdown]
# **Summer (August 2021):**

# %%
# Creating summer DataFrame
nc_ss_summer = nc_ss_day.loc[nc_ss_day.appointment_month=="2021-08",:]

# Viewing the DataFrame
nc_ss_summer
# Out:
#     appointment_date appointment_month            service_setting  \
# 0         2021-08-01           2021-08  Extended Access Provision
# 1         2021-08-01           2021-08           General Practice
# 2         2021-08-01           2021-08                      Other
# 3         2021-08-01           2021-08       Primary Care Network
# 4         2021-08-01           2021-08                   Unmapped
# ..               ...               ...                        ...
# 150       2021-08-31           2021-08  Extended Access Provision
# 151       2021-08-31           2021-08           General Practice
# 152       2021-08-31           2021-08                      Other
# 153       2021-08-31           2021-08       Primary Care Network
# 154       2021-08-31           2021-08                   Unmapped
#
#      count_of_appointments
# 0                      438
# 1                     3411
# 2                      401
# 3                      323
# 4                     1054
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_date',data=nc_ss_summer,ci=None,
             hue='service_setting')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Summer')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Creating autumn DataFrame
nc_ss_autumn = nc_ss_day.loc[nc_ss_day.appointment_month=="2021-10",:]

# Viewing the DataFrame
nc_ss_autumn
# Out:
#     appointment_date appointment_month            service_setting  \
# 305       2021-10-01           2021-10  Extended Access Provision
# 306       2021-10-01           2021-10           General Practice
# 307       2021-10-01           2021-10                      Other
# 308       2021-10-01           2021-10       Primary Care Network
# 309       2021-10-01           2021-10                   Unmapped
# ..               ...               ...                        ...
# 455       2021-10-31           2021-10  Extended Access Provision
# 456       2021-10-31           2021-10           General Practice
# 457       2021-10-31           2021-10                      Other
# 458       2021-10-31           2021-10       Primary Care Network
# 459       2021-10-31           2021-10                   Unmapped
#
#      count_of_appointments
# 305                   7107
# 306                1130646
# 307                  22639
# 308                  22974
# 309                  56201
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_date',data=nc_ss_autumn,ci=None,
             hue='service_setting')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Autumn')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Winter (January 2022):**

# %%
# Creating winter DataFrame
nc_ss_winter = nc_ss_day.loc[nc_ss_day.appointment_month=="2022-01",:]

# Viewing the DataFrame
nc_ss_winter
# Out:
#     appointment_date appointment_month            service_setting  \
# 765       2022-01-01           2022-01  Extended Access Provision
# 766       2022-01-01           2022-01           General Practice
# 767       2022-01-01           2022-01                      Other
# 768       2022-01-01           2022-01       Primary Care Network
# 769       2022-01-01           2022-01                   Unmapped
# ..               ...               ...                        ...
# 915       2022-01-31           2022-01  Extended Access Provision
# 916       2022-01-31           2022-01           General Practice
# 917       2022-01-31           2022-01                      Other
# 918       2022-01-31           2022-01       Primary Care Network
# 919       2022-01-31           2022-01                   Unmapped
#
#      count_of_appointments
# 765                    246
# 766                   3578
# 767                    280
# 768                    215
# 769                    572
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_date',data=nc_ss_winter,ci=None,
             hue='service_setting')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Winter')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Spring (April 2022):**

# %%
# Creating spring DataFrame
nc_ss_spring = nc_ss_day.loc[nc_ss_day.appointment_month=="2022-04",:]

# Viewing the DataFrame
nc_ss_spring
# Out:
#      appointment_date appointment_month            service_setting  \
# 1215       2022-04-01           2022-04  Extended Access Provision
# 1216       2022-04-01           2022-04           General Practice
# 1217       2022-04-01           2022-04                      Other
# 1218       2022-04-01           2022-04       Primary Care Network
# 1219       2022-04-01           2022-04                   Unmapped
# ...               ...               ...                        ...
# 1360       2022-04-30           2022-04  Extended Access Provision
# 1361       2022-04-30           2022-04           General Practice
# 1362       2022-04-30           2022-04                      Other
# 1363       2022-04-30           2022-04       Primary Care Network
# 1364       2022-04-30           2022-04                   Unmapped
#
#       count_of_appointments
# 1215                   8011
# 1216                1085037
# 1217                  21077
# 1218                  26493
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_date',data=nc_ss_spring,ci=None,
             hue='service_setting')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Spring')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# ## Assignment Activity: Analyse the Twitter data

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %% [markdown]
# ### Prepare the workstation

# %%
# Set figure size
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

sns.set_palette('rocket')
sns.color_palette('viridis')
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %% [markdown]
# ### Explore the data set

# %%
# Load the data set
tweets = pd.read_csv("tweets.csv")

# %%
# View the DataFrame
tweets.head(5)
# Out:
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
# Explore the metadata
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
# See the DataFrame statistics
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
# Determining sum of missing values
tweets.isnull().sum()
# Out:
# tweet_id                     0
# tweet_full_text              0
# tweet_entities               0
# tweet_entities_hashtags    167
# tweet_metadata               0
# tweet_retweet_count          0
# tweet_favorite_count         0
# tweet_favorited              0
# tweet_retweeted              0
# tweet_lang                   0
# dtype: int64

# %%
# Explore tweet_retweet_count
tweets.tweet_retweet_count.value_counts()
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64

# %%
# Explore tweet_favorite_count
tweets.tweet_favorite_count.value_counts()
# Out:
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %% [markdown]
# ### Would it be useful to only look at retweeted and favourite tweet messages?

# %% [markdown]
# The idea that certain tweets would hold greater weight or value is certainly subjective, the tweets themselves are opinions from individuals and the value people put on these tweets by favouriing or retweeting further subjectifies the notion of value in a statement.
#
# Furthermore the tweets themselves are not all from the UK and in relation to the NHS so looking at this data solely would not be beneficial as some tweets are about healthcare in different countries.

# %% [markdown]
# ### Review the hashtags

# %%
# Creating a new DataFrame containing only the text
# Dropping non text values keeping object data types only
tweets_text = tweets.drop(['tweet_id','tweet_retweet_count','tweet_favorite_count',
                           'tweet_favorited','tweet_retweeted','tweet_entities',
                           'tweet_metadata','tweet_lang','tweet_entities_hashtags'],axis=1)
# Viewing the dataframe
tweets_text.head(3)
# Out:
#                                                                                                                                                                                            tweet_full_text
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…

# %%
# Creating a new list called tags
tags = []

# %%
# Populating the tags list with a for loop
for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
  for z in y:
    if '#' in z:
      # Change to lowercase.
      tags.append(z.lower())

# %%
# Creating the pandas series
tags = pd.Series(tags)

# %%
# Displaying the first 30 records
tags.head(30)
# Out:
# 0                                    #healthcare
# 1                                 #premisehealth
# 2                                        #hiring
# 3                                    #healthcare
# 4                                        🚨#new:🚨
# 5                                look!\n\n#blogs
# 6                         #digitaltransformation
# 7                                 #cybersecurity
# 8                                    #accounting
# 9                                       #finance
# 10                                   #healthcare
# 11    https://t.co/jrgqeqdme4\n.\n#firstcoastcna
# 12                                      #cnaexam
# 13                           #cnaexampreparation
# 14                                 #jacksonville
# 15                                  #cnatraining
# 16                                        #nurse
# 17                                      #nursing
# 18                                    #nurselife
# ...

# %% [markdown]
# ### Identify the top trending hashtags with a visualisation

# %%
# Create a DataFrame from the series
data = tags.to_frame()

# Resetting the index
data.reset_index(drop=True, inplace=True)

# %%
# Renaming the columns
data.rename(columns={0:"word"},inplace=True)

# Adding a new column for word count
data["word_count"] = 0

# View the DataFrame
data
# Out:
#                     word  word_count
# 0            #healthcare           0
# 1         #premisehealth           0
# 2                #hiring           0
# 3            #healthcare           0
# 4                🚨#new:🚨           0
# ...                  ...         ...
# 4328  #mediqueststaffing           0
# 4329           #hospital           0
# 4330              #shift           0
# 4331     (#newportbeach)           0
# 4332                #job           0
#
# [4333 rows x 2 columns]

# %%
# Count the number of words
count_df = data.groupby(by=["word"]).count()

# Reset the index
count_df = count_df.reset_index()

# Get the new DataFrame as the data
data = count_df

# View the DataFrame
data
# Out:
#                                                    word  word_count
# 0                                               \n\n#ai           3
# 1                            \n\n#arizonabloodandcancer           1
# 2                                          \n\n#biotech           1
# 3                                           \n\n#comedy           5
# 4                                        \n\n#disabili…           1
# ...                                                 ...         ...
# 1749  😄\n\n👉👉https://t.co/j1hvzftqij\n\n#lagossdginvest           1
# 1750                                           😅\n#ih22           1
# 1751                                  🙌🙌\n\n#healthcare           1
# 1752                                            🚨#new:🚨           7
# 1753                                       🤷‍♂️#nursing           1
#
# [1754 rows x 2 columns]

# %%
# Fixing the count data type as int
data['word_count'] = data['word_count'].astype('int')

# %%
# checking the data type of count
data.dtypes
# Out:
# word          object
# word_count     int64
# dtype: object

# %%
# Creating a new DataFrame where count is greater than 10
data_ten = data.loc[data.word_count > 10,:]

# Viewing the DataFrame
data_ten.sort_values('word_count',ascending=False)
# Out:
#                              word  word_count
# 632                   #healthcare         716
# 625                       #health          80
# 919                     #medicine          41
# 131                           #ai          40
# 817                          #job          38
# 894                      #medical          35
# 1350                    #strategy          30
# 1099              #pharmaceutical          28
# 461                #digitalhealth          25
# 1098                      #pharma          25
# 880                    #marketing          25
# 929                   #medtwitter          24
# 354      #competitiveintelligence          24
# 211                      #biotech          24
# 889                        #meded          23
# 720                       #hiring          18
# 1456                     #vaccine          18
# 1386                  #technology          17
# 989                         #news          17
# ...

# %%
# Creating the barplot
sns.barplot(x='word',y='word_count',data = data_ten.sort_values('word_count',ascending=False))
plt.xticks(rotation=90)

plt.title('Hashtags Count > 10')
plt.ylabel('Word Count')
plt.xlabel('Word')
# Out:
# Text(0.5, 0, 'Word')

# %%
# Calculating descriptive statstics to remove outliers
data_ten.describe()
# Out:
#        word_count
# count   47.000000
# mean    34.404255
# std    102.297235
# min     11.000000
# 25%     13.000000
# 50%     16.000000
# 75%     24.000000
# max    716.000000

# %%
# Locating words which are outliers
data_ten.loc[data.word_count > 102,:]
# Out:
#             word  word_count
# 632  #healthcare         716

# %%
# Dropping the overrepresented hashtag 'healthcare' from index 632
data_freq = data_ten.drop([632], axis=0, inplace=True)
# Out:
# /var/folders/nq/syyc0znn1rx1ddrpvmr_d6pw0000gn/T/ipykernel_87154/2798002467.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_freq = data_ten.drop([632], axis=0, inplace=True)

# %%
# Viewing the updated DataFrame
data_ten.sort_values('word_count',ascending=False).head(5)
# Out:
#           word  word_count
# 625    #health          80
# 919  #medicine          41
# 131        #ai          40
# 817       #job          38
# 894   #medical          35

# %%
# Creating the barplot
sns.barplot(x='word',y='word_count',data = data_ten.sort_values('word_count',ascending=False))
plt.xticks(rotation=90)

plt.title('Frequently Used Hashtags')
plt.ylabel('Word Count')
plt.xlabel('Word')
# Out:
# Text(0.5, 0, 'Word')

# %% [markdown]
# ## Assignment Activity: Make recommendations

# %% [markdown]
# ### Investigate the main concerns posed by the NHS.

# %%
# Loading the appointments_regional.csv file
ar = pd.read_csv("appointments_regional.csv")

# Viewing the DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# Printing the min and max dates
print("ar min appointment month:",ar.appointment_month.min())
print("ar max appointment month:",ar.appointment_month.max())
# Out:
# ar min appointment month: 2020-01
# ar max appointment month: 2022-06

# %%
# Filtering the data set to only look at data from 2021-08 onwards
filtered_ar = ar.loc[(ar['appointment_month'] >= '2021-08')
                     & (ar['appointment_month'] < '2022-07')]

# %%
# Printing the new min and max dates
print("ar min appointment month:",filtered_ar.appointment_month.min())
print("ar max appointment month:",filtered_ar.appointment_month.max())
# Out:
# ar min appointment month: 2021-08
# ar max appointment month: 2022-06

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Creating an aggregated data set to review the different features
ar_agg = filtered_ar.groupby(by=["appointment_month","hcp_type","appointment_status",
                            "appointment_mode","time_between_book_and_appointment","icb_ons_code"]).sum()

# Resetting the index
ar_agg = ar_agg.reset_index()

# Viewing the new DataFrame
ar_agg
# Out:
#        appointment_month hcp_type appointment_status appointment_mode  \
# 0                2021-08       GP           Attended     Face-to-Face
# 1                2021-08       GP           Attended     Face-to-Face
# 2                2021-08       GP           Attended     Face-to-Face
# 3                2021-08       GP           Attended     Face-to-Face
# 4                2021-08       GP           Attended     Face-to-Face
# ...                  ...      ...                ...              ...
# 108973           2022-06  Unknown            Unknown          Unknown
# 108974           2022-06  Unknown            Unknown          Unknown
# 108975           2022-06  Unknown            Unknown          Unknown
# 108976           2022-06  Unknown            Unknown          Unknown
# 108977           2022-06  Unknown            Unknown     Video/Online
#
#        time_between_book_and_appointment icb_ons_code  count_of_appointments
# ...

# %%
# Creating the new DataFrame
ar_df = ar_agg.groupby(by='appointment_month').sum()

# Resetting the index
ar_df = ar_df.reset_index()

# Adding the new column for utilisation
ar_df["utilisation"] = ar_df["count_of_appointments"] / 30

# Rounding the utilisation column
ar_df['utilisation'] = ar_df['utilisation'].round(1)

# Viewing the DataFrame
ar_df
# Out:
#    appointment_month  count_of_appointments  utilisation
# 0            2021-08               23852171     795072.4
# 1            2021-09               28522501     950750.0
# 2            2021-10               30303834    1010127.8
# 3            2021-11               30405070    1013502.3
# 4            2021-12               25140776     838025.9
# 5            2022-01               25635474     854515.8
# 6            2022-02               25355260     845175.3
# 7            2022-03               29595038     986501.3
# 8            2022-04               23913060     797102.0
# 9            2022-05               27495508     916516.9
# 10           2022-06               25828078     860935.9

# %%
# Checking the maximum value of utilization
ar_df['utilisation'].max()
# Out:
# 1013502.3

# %% [markdown]
# * Since maximum value of utilisation is less than 1,200,000 , this month was below capacity and services were not 100% utilised

# %%
# Calculating the percentage utilisation for each month
ar_df["percentage_utilised"] = (ar_df["utilisation"] / 1200000)*100

# Rounding the DataFrame
ar_df['percentage_utilised'] = ar_df['percentage_utilised'].round(1)

# Viewing the DataFrame
ar_df
# Out:
#    appointment_month  count_of_appointments  utilisation  percentage_utilised
# 0            2021-08               23852171     795072.4                 66.3
# 1            2021-09               28522501     950750.0                 79.2
# 2            2021-10               30303834    1010127.8                 84.2
# 3            2021-11               30405070    1013502.3                 84.5
# 4            2021-12               25140776     838025.9                 69.8
# 5            2022-01               25635474     854515.8                 71.2
# 6            2022-02               25355260     845175.3                 70.4
# 7            2022-03               29595038     986501.3                 82.2
# 8            2022-04               23913060     797102.0                 66.4
# 9            2022-05               27495508     916516.9                 76.4
# 10           2022-06               25828078     860935.9                 71.7

# %% [markdown]
# **Number of monthly visits**

# %%
# Changing the data type of appointment month
ar_df['appointment_month'] = ar_df['appointment_month'].astype('str') 

# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=ar_df,ci=None)

plt.title('Number of Monthly Visits')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Monthly capacity utilisation**

# %%
# Plotting
ar_df['Max_Capacity'] = 1200000
sns.lineplot(x='appointment_month',y='utilisation',data=ar_df,ci=None)
sns.lineplot(x='appointment_month', y='Max_Capacity',data=ar_df,ci=None)

plt.title('Utilisation v Max Capacity')
plt.ylabel('Utilisation')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Creating the new D
hcp_df = filtered_ar.groupby(by=['hcp_type','appointment_month']).sum()

# Resetting the index
hcp_df = hcp_df.reset_index()

# Viewing the DataFrame
hcp_df.head(15)
# Out:
#                 hcp_type appointment_month  count_of_appointments
# 0                     GP           2021-08               12299022
# 1                     GP           2021-09               14487785
# 2                     GP           2021-10               14300751
# 3                     GP           2021-11               14897749
# 4                     GP           2021-12               12654767
# 5                     GP           2022-01               13138050
# 6                     GP           2022-02               12869711
# 7                     GP           2022-03               15127227
# 8                     GP           2022-04               11908463
# 9                     GP           2022-05               13793934
# 10                    GP           2022-06               12893983
# 11  Other Practice staff           2021-08               10797821
# 12  Other Practice staff           2021-09               13126731
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=hcp_df,ci=None,
             hue='hcp_type')

plt.title('Healthcare Professional Types v Months')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Creating the new DataFrame
status_df = filtered_ar.groupby(by=['appointment_status','appointment_month']).sum()

# Resetting the index
status_df = status_df.reset_index()

# View the DataFrame
status_df.head(15)
# Out:
#    appointment_status appointment_month  count_of_appointments
# 0            Attended           2021-08               22081765
# 1            Attended           2021-09               25757066
# 2            Attended           2021-10               27170506
# 3            Attended           2021-11               27667665
# 4            Attended           2021-12               22853483
# 5            Attended           2022-01               23597196
# 6            Attended           2022-02               23351939
# 7            Attended           2022-03               27170002
# 8            Attended           2022-04               21948814
# 9            Attended           2022-05               25343941
# 10           Attended           2022-06               23715317
# 11                DNA           2021-08                 949137
# 12                DNA           2021-09                1321348
# 13                DNA           2021-10                1565624
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=status_df,ci=None,hue='appointment_status')

plt.title('Appointment Statuses v Months')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %%
# Dropping all the rows with the overrepresented attended status
status_df_noa = status_df.drop(status_df[status_df.appointment_status == 'Attended'].index)

# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=status_df_noa,ci=None,
             hue='appointment_status')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Appointment Statuses v Months No Attended Status')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Creating the new DataFrame
type_df = filtered_ar.groupby(by=['appointment_mode','appointment_month']).sum()

#resetting the index
type_df = type_df.reset_index()

#view the dataframe
type_df.head(15)
# Out:
#    appointment_mode appointment_month  count_of_appointments
# 0      Face-to-Face           2021-08               13717325
# 1      Face-to-Face           2021-09               17266602
# 2      Face-to-Face           2021-10               19471561
# 3      Face-to-Face           2021-11               19031327
# 4      Face-to-Face           2021-12               15312340
# 5      Face-to-Face           2022-01               15414102
# 6      Face-to-Face           2022-02               15531971
# 7      Face-to-Face           2022-03               18333743
# 8      Face-to-Face           2022-04               15049567
# 9      Face-to-Face           2022-05               17630858
# 10     Face-to-Face           2022-06               16744191
# 11       Home Visit           2021-08                 151619
# 12       Home Visit           2021-09                 171829
# 13       Home Visit           2021-10                 178593
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=type_df,ci=None,
             hue='appointment_mode')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Appointment Type v Months')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Creating the new DataFrame
time_b_df = filtered_ar.groupby(by=['time_between_book_and_appointment','appointment_month']).sum()

#resetting the index
time_b_df = time_b_df.reset_index()

#view the dataframe
time_b_df.head(15)
# Out:
#    time_between_book_and_appointment appointment_month  count_of_appointments
# 0                              1 Day           2021-08                2018319
# 1                              1 Day           2021-09                2666072
# 2                              1 Day           2021-10                2598516
# 3                              1 Day           2021-11                2506532
# 4                              1 Day           2021-12                2219212
# 5                              1 Day           2022-01                2334274
# 6                              1 Day           2022-02                2272923
# 7                              1 Day           2022-03                2709362
# 8                              1 Day           2022-04                2088881
# 9                              1 Day           2022-05                2270686
# 10                             1 Day           2022-06                2188197
# ...

# %%
# Plotting
sns.lineplot(y='count_of_appointments',x='appointment_month',data=time_b_df,ci=None,
             hue='time_between_book_and_appointment')

plt.legend(bbox_to_anchor=(1, 1),loc='upper left',borderaxespad=0)
plt.title('Time Between Appointment v Months')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %%
sns.barplot(x='time_between_book_and_appointment',y='count_of_appointments',data=time_b_df,
            hue='time_between_book_and_appointment')

plt.legend(bbox_to_anchor=(1,1),loc='upper left',borderaxespad=0)
plt.title('Time Between Appointment v Count of Appointments')
plt.ylabel('Count of Appointments')
plt.xlabel('Appointment Month')
# Out:
# Text(0.5, 0, 'Appointment Month')

# %% [markdown]
# **Question:** How do the spread of service settings compare?

# %%
# Plotting service settings
sns.boxplot(data=nc, x='service_setting', y='count_of_appointments')
# Out:
# <AxesSubplot:xlabel='service_setting', ylabel='count_of_appointments'>

# %%
# Dropping all the rows with the overrepresented general practice 
nc_no_gp = nc.drop(nc[nc.service_setting == "General Practice"].index)

sns.boxplot(data=nc_no_gp, x='service_setting', y='count_of_appointments')
# Out:
# <AxesSubplot:xlabel='service_setting', ylabel='count_of_appointments'>

# %% [markdown]
# ### Provide a summary of your findings and recommendations based on the analysis.

# %% [markdown]
# > Summary can be found in the Report document
